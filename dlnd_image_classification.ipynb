# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:24, 6.93MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 80
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 80:
# Image - Min Value: 0 Max Value: 221
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = x.astype(np.float32)
    x /=255
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ## One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    a = np.zeros((len(x), 10))
    for i in range(0, len(x)):
        np.put(a[i], x[i], 1)
    return a  
        
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype = tf.float32, shape=(None, *image_shape), name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype = tf.int32, shape=(None, n_classes), name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype = tf.float32, shape = (None), name = "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #parameters
    weight = tf.Variable(tf.truncated_normal(shape=(conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs), mean = 0, stddev = 0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    #conv net, bias, nonlinear activation
    conv = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv = tf.nn.bias_add(conv, bias)
    conv = tf.nn.relu(conv)
    
    #max pooling
    conv = tf.nn.max_pool(conv, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    
    return conv

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement 
    # Get the shape of x_tensor
    x_tensor_shape = x_tensor.get_shape()
    
    # Calculate the number of features = img_height * img_width * num_channels
    num_features = x_tensor_shape[1:4].num_elements()
    
    # Return the flattend tensor
    layer_flat = tf.reshape(x_tensor, [-1, num_features])
    return layer_flat


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    #parameters
    weights = tf.Variable(tf.truncated_normal(shape=(x_tensor.get_shape().as_list()[1], num_outputs), mean = 0, stddev = 0.1))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    #fully connected layer
    fully_conn = tf.add(tf.matmul(x_tensor, weights), biases)
    fully_conn = tf.nn.relu(fully_conn)
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    #parameters
    weights = tf.Variable(tf.truncated_normal(shape=(x_tensor.get_shape().as_list()[1], num_outputs), mean = 0, stddev = 0.1))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    #output layer
    output = tf.add(tf.matmul(x_tensor, weights), biases)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, 32, (3, 3), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 64, (3, 3), (1, 1), (2, 2), (2, 2))
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 500)
    x = fully_conn(x, 250)
    x = tf.nn.dropout(x, keep_prob)
     
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print("cost: ", session.run(cost, feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0}))
    print("accuracy: ", session.run(accuracy, feed_dict = {x: valid_features, y: valid_labels, keep_prob: 1.0}))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 64
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  cost:  1.8426
# accuracy:  0.3832
# Epoch  2, CIFAR-10 Batch 1:  cost:  1.68317
# accuracy:  0.438
# Epoch  3, CIFAR-10 Batch 1:  cost:  1.4355
# accuracy:  0.5176
# Epoch  4, CIFAR-10 Batch 1:  cost:  1.33768
# accuracy:  0.5226
# Epoch  5, CIFAR-10 Batch 1:  cost:  1.19054
# accuracy:  0.53
# Epoch  6, CIFAR-10 Batch 1:  cost:  1.05854
# accuracy:  0.56
# Epoch  7, CIFAR-10 Batch 1:  cost:  0.907776
# accuracy:  0.5712
# Epoch  8, CIFAR-10 Batch 1:  cost:  0.812336
# accuracy:  0.5808
# Epoch  9, CIFAR-10 Batch 1:  cost:  0.712135
# accuracy:  0.5864
# Epoch 10, CIFAR-10 Batch 1:  cost:  0.643659
# accuracy:  0.5928
# Epoch 11, CIFAR-10 Batch 1:  cost:  0.599094
# accuracy:  0.6036
# Epoch 12, CIFAR-10 Batch 1:  cost:  0.495307
# accuracy:  0.61
# Epoch 13, CIFAR-10 Batch 1:  cost:  0.422159
# accuracy:  0.609
# Epoch 14, CIFAR-10 Batch 1:  cost:  0.360691
# accuracy:  0.6134
# Epoch 15, CIFAR-10 Batch 1:  cost:  0.253201
# accuracy:  0.596
# Epoch 16, CIFAR-10 Batch 1:  cost:  0.217593
# accuracy:  0.5994
# Epoch 17, CIFAR-10 Batch 1:  cost:  0.151348
# accuracy:  0.6064
# Epoch 18, CIFAR-10 Batch 1:  cost:  0.138175
# accuracy:  0.6076
# Epoch 19, CIFAR-10 Batch 1:  cost:  0.10904
# accuracy:  0.6204
# Epoch 20, CIFAR-10 Batch 1:  cost:  0.0747171
# accuracy:  0.6242
# Epoch 21, CIFAR-10 Batch 1:  cost:  0.0464957
# accuracy:  0.6266
# Epoch 22, CIFAR-10 Batch 1:  cost:  0.0280261
# accuracy:  0.622
# Epoch 23, CIFAR-10 Batch 1:  cost:  0.0245946
# accuracy:  0.6182
# Epoch 24, CIFAR-10 Batch 1:  cost:  0.019797
# accuracy:  0.6292
# Epoch 25, CIFAR-10 Batch 1:  cost:  0.0205175
# accuracy:  0.6236
# Epoch 26, CIFAR-10 Batch 1:  cost:  0.0129205
# accuracy:  0.6242
# Epoch 27, CIFAR-10 Batch 1:  cost:  0.011336
# accuracy:  0.6216
# Epoch 28, CIFAR-10 Batch 1:  cost:  0.00799819
# accuracy:  0.6326
# Epoch 29, CIFAR-10 Batch 1:  cost:  0.0160787
# accuracy:  0.6234
# Epoch 30, CIFAR-10 Batch 1:  cost:  0.0127872
# accuracy:  0.6178
# Epoch 31, CIFAR-10 Batch 1:  cost:  0.00816386
# accuracy:  0.624
# Epoch 32, CIFAR-10 Batch 1:  cost:  0.00512123
# accuracy:  0.616
# Epoch 33, CIFAR-10 Batch 1:  cost:  0.00563126
# accuracy:  0.6266
# Epoch 34, CIFAR-10 Batch 1:  cost:  0.00942146
# accuracy:  0.6238
# Epoch 35, CIFAR-10 Batch 1:  cost:  0.00477546
# accuracy:  0.6226
# Epoch 36, CIFAR-10 Batch 1:  cost:  0.00272972
# accuracy:  0.6218
# Epoch 37, CIFAR-10 Batch 1:  cost:  0.00305307
# accuracy:  0.6294
# Epoch 38, CIFAR-10 Batch 1:  cost:  0.00262803
# accuracy:  0.6288
# Epoch 39, CIFAR-10 Batch 1:  cost:  0.00190353
# accuracy:  0.625
# Epoch 40, CIFAR-10 Batch 1:  cost:  0.00236669
# accuracy:  0.626
# Epoch 41, CIFAR-10 Batch 1:  cost:  0.00216098
# accuracy:  0.624
# Epoch 42, CIFAR-10 Batch 1:  cost:  0.000935623
# accuracy:  0.621
# Epoch 43, CIFAR-10 Batch 1:  cost:  0.000720104
# accuracy:  0.6166
# Epoch 44, CIFAR-10 Batch 1:  cost:  0.00212635
# accuracy:  0.6114
# Epoch 45, CIFAR-10 Batch 1:  cost:  0.00150548
# accuracy:  0.6148
# Epoch 46, CIFAR-10 Batch 1:  cost:  0.00268285
# accuracy:  0.6106
# Epoch 47, CIFAR-10 Batch 1:  cost:  0.00101637
# accuracy:  0.621
# Epoch 48, CIFAR-10 Batch 1:  cost:  0.00597016
# accuracy:  0.5914
# Epoch 49, CIFAR-10 Batch 1:  cost:  0.000762674
# accuracy:  0.6168
# Epoch 50, CIFAR-10 Batch 1:  cost:  0.00032686
# accuracy:  0.6246
# Epoch 51, CIFAR-10 Batch 1:  cost:  0.000310607
# accuracy:  0.6202
# Epoch 52, CIFAR-10 Batch 1:  cost:  0.000686154
# accuracy:  0.627
# Epoch 53, CIFAR-10 Batch 1:  cost:  0.000670059
# accuracy:  0.6232
# Epoch 54, CIFAR-10 Batch 1:  cost:  0.000685657
# accuracy:  0.6156
# Epoch 55, CIFAR-10 Batch 1:  cost:  0.000388715
# accuracy:  0.6204
# Epoch 56, CIFAR-10 Batch 1:  cost:  0.000384362
# accuracy:  0.6154
# Epoch 57, CIFAR-10 Batch 1:  cost:  0.000678331
# accuracy:  0.6246
# Epoch 58, CIFAR-10 Batch 1:  cost:  0.000310075
# accuracy:  0.6168
# Epoch 59, CIFAR-10 Batch 1:  cost:  9.31146e-05
# accuracy:  0.6206
# Epoch 60, CIFAR-10 Batch 1:  cost:  5.30658e-05
# accuracy:  0.6288

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  cost:  1.8223
# accuracy:  0.3724
# Epoch  1, CIFAR-10 Batch 2:  cost:  1.49893
# accuracy:  0.458
# Epoch  1, CIFAR-10 Batch 3:  cost:  1.13459
# accuracy:  0.5052
# Epoch  1, CIFAR-10 Batch 4:  cost:  1.20906
# accuracy:  0.5388
# Epoch  1, CIFAR-10 Batch 5:  cost:  1.34411
# accuracy:  0.5594
# Epoch  2, CIFAR-10 Batch 1:  cost:  1.37394
# accuracy:  0.5696
# Epoch  2, CIFAR-10 Batch 2:  cost:  1.12338
# accuracy:  0.5842
# Epoch  2, CIFAR-10 Batch 3:  cost:  0.926021
# accuracy:  0.5966
# Epoch  2, CIFAR-10 Batch 4:  cost:  0.930908
# accuracy:  0.6112
# Epoch  2, CIFAR-10 Batch 5:  cost:  1.02177
# accuracy:  0.6328
# Epoch  3, CIFAR-10 Batch 1:  cost:  1.20113
# accuracy:  0.6318
# Epoch  3, CIFAR-10 Batch 2:  cost:  0.886445
# accuracy:  0.6358
# Epoch  3, CIFAR-10 Batch 3:  cost:  0.820369
# accuracy:  0.6414
# Epoch  3, CIFAR-10 Batch 4:  cost:  0.850746
# accuracy:  0.6508
# Epoch  3, CIFAR-10 Batch 5:  cost:  0.840088
# accuracy:  0.6486
# Epoch  4, CIFAR-10 Batch 1:  cost:  0.957685
# accuracy:  0.6568
# Epoch  4, CIFAR-10 Batch 2:  cost:  0.822641
# accuracy:  0.672
# Epoch  4, CIFAR-10 Batch 3:  cost:  0.663107
# accuracy:  0.6722
# Epoch  4, CIFAR-10 Batch 4:  cost:  0.674187
# accuracy:  0.6716
# Epoch  4, CIFAR-10 Batch 5:  cost:  0.653247
# accuracy:  0.6826
# Epoch  5, CIFAR-10 Batch 1:  cost:  0.822802
# accuracy:  0.6848
# Epoch  5, CIFAR-10 Batch 2:  cost:  0.654164
# accuracy:  0.6902
# Epoch  5, CIFAR-10 Batch 3:  cost:  0.546392
# accuracy:  0.6816
# Epoch  5, CIFAR-10 Batch 4:  cost:  0.59241
# accuracy:  0.6982
# Epoch  5, CIFAR-10 Batch 5:  cost:  0.547056
# accuracy:  0.7006
# Epoch  6, CIFAR-10 Batch 1:  cost:  0.71995
# accuracy:  0.7014
# Epoch  6, CIFAR-10 Batch 2:  cost:  0.553692
# accuracy:  0.6938
# Epoch  6, CIFAR-10 Batch 3:  cost:  0.420757
# accuracy:  0.703
# Epoch  6, CIFAR-10 Batch 4:  cost:  0.535775
# accuracy:  0.7034
# Epoch  6, CIFAR-10 Batch 5:  cost:  0.462875
# accuracy:  0.7068
# Epoch  7, CIFAR-10 Batch 1:  cost:  0.629691
# accuracy:  0.706
# Epoch  7, CIFAR-10 Batch 2:  cost:  0.456351
# accuracy:  0.7108
# Epoch  7, CIFAR-10 Batch 3:  cost:  0.424554
# accuracy:  0.7168
# Epoch  7, CIFAR-10 Batch 4:  cost:  0.377481
# accuracy:  0.7128
# Epoch  7, CIFAR-10 Batch 5:  cost:  0.375031
# accuracy:  0.725
# Epoch  8, CIFAR-10 Batch 1:  cost:  0.520477
# accuracy:  0.7142
# Epoch  8, CIFAR-10 Batch 2:  cost:  0.375552
# accuracy:  0.7214
# Epoch  8, CIFAR-10 Batch 3:  cost:  0.350839
# accuracy:  0.734
# Epoch  8, CIFAR-10 Batch 4:  cost:  0.321794
# accuracy:  0.719
# Epoch  8, CIFAR-10 Batch 5:  cost:  0.287528
# accuracy:  0.7282
# Epoch  9, CIFAR-10 Batch 1:  cost:  0.425039
# accuracy:  0.7252
# Epoch  9, CIFAR-10 Batch 2:  cost:  0.329689
# accuracy:  0.7352
# Epoch  9, CIFAR-10 Batch 3:  cost:  0.332809
# accuracy:  0.7304
# Epoch  9, CIFAR-10 Batch 4:  cost:  0.243115
# accuracy:  0.7284
# Epoch  9, CIFAR-10 Batch 5:  cost:  0.273613
# accuracy:  0.7264
# Epoch 10, CIFAR-10 Batch 1:  cost:  0.373704
# accuracy:  0.7184
# Epoch 10, CIFAR-10 Batch 2:  cost:  0.253604
# accuracy:  0.7324
# Epoch 10, CIFAR-10 Batch 3:  cost:  0.24295
# accuracy:  0.7482
# Epoch 10, CIFAR-10 Batch 4:  cost:  0.18216
# accuracy:  0.731
# Epoch 10, CIFAR-10 Batch 5:  cost:  0.246978
# accuracy:  0.7318
# Epoch 11, CIFAR-10 Batch 1:  cost:  0.285275
# accuracy:  0.7248
# Epoch 11, CIFAR-10 Batch 2:  cost:  0.237529
# accuracy:  0.7372
# Epoch 11, CIFAR-10 Batch 3:  cost:  0.198751
# accuracy:  0.7376
# Epoch 11, CIFAR-10 Batch 4:  cost:  0.158989
# accuracy:  0.7314
# Epoch 11, CIFAR-10 Batch 5:  cost:  0.17422
# accuracy:  0.7384
# Epoch 12, CIFAR-10 Batch 1:  cost:  0.264403
# accuracy:  0.729
# Epoch 12, CIFAR-10 Batch 2:  cost:  0.171553
# accuracy:  0.736
# Epoch 12, CIFAR-10 Batch 3:  cost:  0.171712
# accuracy:  0.7448
# Epoch 12, CIFAR-10 Batch 4:  cost:  0.104911
# accuracy:  0.732
# Epoch 12, CIFAR-10 Batch 5:  cost:  0.186244
# accuracy:  0.7342
# Epoch 13, CIFAR-10 Batch 1:  cost:  0.255848
# accuracy:  0.7338
# Epoch 13, CIFAR-10 Batch 2:  cost:  0.124784
# accuracy:  0.7286
# Epoch 13, CIFAR-10 Batch 3:  cost:  0.173659
# accuracy:  0.7446
# Epoch 13, CIFAR-10 Batch 4:  cost:  0.0998746
# accuracy:  0.7366
# Epoch 13, CIFAR-10 Batch 5:  cost:  0.138589
# accuracy:  0.73
# Epoch 14, CIFAR-10 Batch 1:  cost:  0.130695
# accuracy:  0.749
# Epoch 14, CIFAR-10 Batch 2:  cost:  0.125966
# accuracy:  0.7328
# Epoch 14, CIFAR-10 Batch 3:  cost:  0.130372
# accuracy:  0.7446
# Epoch 14, CIFAR-10 Batch 4:  cost:  0.0664562
# accuracy:  0.7212
# Epoch 14, CIFAR-10 Batch 5:  cost:  0.0998979
# accuracy:  0.7396
# Epoch 15, CIFAR-10 Batch 1:  cost:  0.140947
# accuracy:  0.7472
# Epoch 15, CIFAR-10 Batch 2:  cost:  0.106812
# accuracy:  0.7314
# Epoch 15, CIFAR-10 Batch 3:  cost:  0.140739
# accuracy:  0.7374
# Epoch 15, CIFAR-10 Batch 4:  cost:  0.0553512
# accuracy:  0.74
# Epoch 15, CIFAR-10 Batch 5:  cost:  0.0793987
# accuracy:  0.7334
# Epoch 16, CIFAR-10 Batch 1:  cost:  0.0925703
# accuracy:  0.7436
# Epoch 16, CIFAR-10 Batch 2:  cost:  0.119885
# accuracy:  0.7384
# Epoch 16, CIFAR-10 Batch 3:  cost:  0.107695
# accuracy:  0.7424
# Epoch 16, CIFAR-10 Batch 4:  cost:  0.0640777
# accuracy:  0.7174
# Epoch 16, CIFAR-10 Batch 5:  cost:  0.0663393
# accuracy:  0.745
# Epoch 17, CIFAR-10 Batch 1:  cost:  0.0824795
# accuracy:  0.746
# Epoch 17, CIFAR-10 Batch 2:  cost:  0.0626863
# accuracy:  0.7314
# Epoch 17, CIFAR-10 Batch 3:  cost:  0.0917186
# accuracy:  0.7374
# Epoch 17, CIFAR-10 Batch 4:  cost:  0.036518
# accuracy:  0.7422
# Epoch 17, CIFAR-10 Batch 5:  cost:  0.0959627
# accuracy:  0.744
# Epoch 18, CIFAR-10 Batch 1:  cost:  0.0851232
# accuracy:  0.7286
# Epoch 18, CIFAR-10 Batch 2:  cost:  0.0352222
# accuracy:  0.7434
# Epoch 18, CIFAR-10 Batch 3:  cost:  0.0655583
# accuracy:  0.7422
# Epoch 18, CIFAR-10 Batch 4:  cost:  0.0277875
# accuracy:  0.732
# Epoch 18, CIFAR-10 Batch 5:  cost:  0.136945
# accuracy:  0.747
# Epoch 19, CIFAR-10 Batch 1:  cost:  0.0485347
# accuracy:  0.7424
# Epoch 19, CIFAR-10 Batch 2:  cost:  0.0543353
# accuracy:  0.7368
# Epoch 19, CIFAR-10 Batch 3:  cost:  0.0710104
# accuracy:  0.7388
# Epoch 19, CIFAR-10 Batch 4:  cost:  0.0205666
# accuracy:  0.737
# Epoch 19, CIFAR-10 Batch 5:  cost:  0.0705284
# accuracy:  0.7374
# Epoch 20, CIFAR-10 Batch 1:  cost:  0.0577385
# accuracy:  0.7444
# Epoch 20, CIFAR-10 Batch 2:  cost:  0.0334876
# accuracy:  0.7352
# Epoch 20, CIFAR-10 Batch 3:  cost:  0.0699851
# accuracy:  0.7328
# Epoch 20, CIFAR-10 Batch 4:  cost:  0.015143
# accuracy:  0.7346
# Epoch 20, CIFAR-10 Batch 5:  cost:  0.0690421
# accuracy:  0.7434
# Epoch 21, CIFAR-10 Batch 1:  cost:  0.0378826
# accuracy:  0.7516
# Epoch 21, CIFAR-10 Batch 2:  cost:  0.0275125
# accuracy:  0.7432
# Epoch 21, CIFAR-10 Batch 3:  cost:  0.047057
# accuracy:  0.74
# Epoch 21, CIFAR-10 Batch 4:  cost:  0.0246054
# accuracy:  0.7226
# Epoch 21, CIFAR-10 Batch 5:  cost:  0.0427376
# accuracy:  0.742
# Epoch 22, CIFAR-10 Batch 1:  cost:  0.0270857
# accuracy:  0.75
# Epoch 22, CIFAR-10 Batch 2:  cost:  0.0342555
# accuracy:  0.743
# Epoch 22, CIFAR-10 Batch 3:  cost:  0.0556245
# accuracy:  0.736
# Epoch 22, CIFAR-10 Batch 4:  cost:  0.0212375
# accuracy:  0.7394
# Epoch 22, CIFAR-10 Batch 5:  cost:  0.0199416
# accuracy:  0.7414
# Epoch 23, CIFAR-10 Batch 1:  cost:  0.0359649
# accuracy:  0.7538
# Epoch 23, CIFAR-10 Batch 2:  cost:  0.0181694
# accuracy:  0.7402
# Epoch 23, CIFAR-10 Batch 3:  cost:  0.0171152
# accuracy:  0.741
# Epoch 23, CIFAR-10 Batch 4:  cost:  0.0174775
# accuracy:  0.7468
# Epoch 23, CIFAR-10 Batch 5:  cost:  0.0275123
# accuracy:  0.7368
# Epoch 24, CIFAR-10 Batch 1:  cost:  0.0262115
# accuracy:  0.7446
# Epoch 24, CIFAR-10 Batch 2:  cost:  0.0185765
# accuracy:  0.7434
# Epoch 24, CIFAR-10 Batch 3:  cost:  0.0256144
# accuracy:  0.7368
# Epoch 24, CIFAR-10 Batch 4:  cost:  0.0378919
# accuracy:  0.7492
# Epoch 24, CIFAR-10 Batch 5:  cost:  0.0220413
# accuracy:  0.7458
# Epoch 25, CIFAR-10 Batch 1:  cost:  0.014079
# accuracy:  0.7488
# Epoch 25, CIFAR-10 Batch 2:  cost:  0.0192249
# accuracy:  0.739
# Epoch 25, CIFAR-10 Batch 3:  cost:  0.0148716
# accuracy:  0.7344
# Epoch 25, CIFAR-10 Batch 4:  cost:  0.00949659
# accuracy:  0.7386
# Epoch 25, CIFAR-10 Batch 5:  cost:  0.00889959
# accuracy:  0.747
# Epoch 26, CIFAR-10 Batch 1:  cost:  0.0255274
# accuracy:  0.7508
# Epoch 26, CIFAR-10 Batch 2:  cost:  0.00498765
# accuracy:  0.7538
# Epoch 26, CIFAR-10 Batch 3:  cost:  0.0190619
# accuracy:  0.7434
# Epoch 26, CIFAR-10 Batch 4:  cost:  0.0188639
# accuracy:  0.7426
# Epoch 26, CIFAR-10 Batch 5:  cost:  0.0112185
# accuracy:  0.7396
# Epoch 27, CIFAR-10 Batch 1:  cost:  0.0133623
# accuracy:  0.7528
# Epoch 27, CIFAR-10 Batch 2:  cost:  0.0208928
# accuracy:  0.7406
# Epoch 27, CIFAR-10 Batch 3:  cost:  0.00800529
# accuracy:  0.7402
# Epoch 27, CIFAR-10 Batch 4:  cost:  0.0171055
# accuracy:  0.7586
# Epoch 27, CIFAR-10 Batch 5:  cost:  0.00911989
# accuracy:  0.7478
# Epoch 28, CIFAR-10 Batch 1:  cost:  0.0276073
# accuracy:  0.7488
# Epoch 28, CIFAR-10 Batch 2:  cost:  0.00610435
# accuracy:  0.7504
# Epoch 28, CIFAR-10 Batch 3:  cost:  0.0260837
# accuracy:  0.7268
# Epoch 28, CIFAR-10 Batch 4:  cost:  0.0162756
# accuracy:  0.7526
# Epoch 28, CIFAR-10 Batch 5:  cost:  0.0137424
# accuracy:  0.7424
# Epoch 29, CIFAR-10 Batch 1:  cost:  0.0115957
# accuracy:  0.7562
# Epoch 29, CIFAR-10 Batch 2:  cost:  0.00966545
# accuracy:  0.749
# Epoch 29, CIFAR-10 Batch 3:  cost:  0.0302447
# accuracy:  0.7402
# Epoch 29, CIFAR-10 Batch 4:  cost:  0.0074499
# accuracy:  0.7452
# Epoch 29, CIFAR-10 Batch 5:  cost:  0.00298512
# accuracy:  0.7524
# Epoch 30, CIFAR-10 Batch 1:  cost:  0.00928196
# accuracy:  0.7466
# Epoch 30, CIFAR-10 Batch 2:  cost:  0.00291785
# accuracy:  0.7416
# Epoch 30, CIFAR-10 Batch 3:  cost:  0.0428219
# accuracy:  0.7356
# Epoch 30, CIFAR-10 Batch 4:  cost:  0.00985797
# accuracy:  0.7406
# Epoch 30, CIFAR-10 Batch 5:  cost:  0.00344315
# accuracy:  0.7444
# Epoch 31, CIFAR-10 Batch 1:  cost:  0.018491
# accuracy:  0.7478
# Epoch 31, CIFAR-10 Batch 2:  cost:  0.00801798
# accuracy:  0.7416
# Epoch 31, CIFAR-10 Batch 3:  cost:  0.0336161
# accuracy:  0.7474
# Epoch 31, CIFAR-10 Batch 4:  cost:  0.00396235
# accuracy:  0.7472
# Epoch 31, CIFAR-10 Batch 5:  cost:  0.0130559
# accuracy:  0.7422
# Epoch 32, CIFAR-10 Batch 1:  cost:  0.00835727
# accuracy:  0.751
# Epoch 32, CIFAR-10 Batch 2:  cost:  0.0052237
# accuracy:  0.7404
# Epoch 32, CIFAR-10 Batch 3:  cost:  0.00660224
# accuracy:  0.7472
# Epoch 32, CIFAR-10 Batch 4:  cost:  0.00110205
# accuracy:  0.7474
# Epoch 32, CIFAR-10 Batch 5:  cost:  0.00583995
# accuracy:  0.749
# Epoch 33, CIFAR-10 Batch 1:  cost:  0.00724114
# accuracy:  0.7516
# Epoch 33, CIFAR-10 Batch 2:  cost:  0.00118547
# accuracy:  0.7516
# Epoch 33, CIFAR-10 Batch 3:  cost:  0.00478333
# accuracy:  0.734
# Epoch 33, CIFAR-10 Batch 4:  cost:  0.00812129
# accuracy:  0.758
# Epoch 33, CIFAR-10 Batch 5:  cost:  0.00439839
# accuracy:  0.7512
# Epoch 34, CIFAR-10 Batch 1:  cost:  0.00556924
# accuracy:  0.7574
# Epoch 34, CIFAR-10 Batch 2:  cost:  0.00289838
# accuracy:  0.7556
# Epoch 34, CIFAR-10 Batch 3:  cost:  0.00218081
# accuracy:  0.7414
# Epoch 34, CIFAR-10 Batch 4:  cost:  0.00290568
# accuracy:  0.7374
# Epoch 34, CIFAR-10 Batch 5:  cost:  0.00428035
# accuracy:  0.739
# Epoch 35, CIFAR-10 Batch 1:  cost:  0.00623981
# accuracy:  0.7486
# Epoch 35, CIFAR-10 Batch 2:  cost:  0.00203626
# accuracy:  0.7416
# Epoch 35, CIFAR-10 Batch 3:  cost:  0.00132253
# accuracy:  0.752
# Epoch 35, CIFAR-10 Batch 4:  cost:  0.00191233
# accuracy:  0.7486
# Epoch 35, CIFAR-10 Batch 5:  cost:  0.00328737
# accuracy:  0.7434
# Epoch 36, CIFAR-10 Batch 1:  cost:  0.00747206
# accuracy:  0.744
# Epoch 36, CIFAR-10 Batch 2:  cost:  0.00299072
# accuracy:  0.7564
# Epoch 36, CIFAR-10 Batch 3:  cost:  0.0144243
# accuracy:  0.7334
# Epoch 36, CIFAR-10 Batch 4:  cost:  0.00801319
# accuracy:  0.7448
# Epoch 36, CIFAR-10 Batch 5:  cost:  0.0016425
# accuracy:  0.7434
# Epoch 37, CIFAR-10 Batch 1:  cost:  0.000789313
# accuracy:  0.755
# Epoch 37, CIFAR-10 Batch 2:  cost:  0.00192726
# accuracy:  0.7462
# Epoch 37, CIFAR-10 Batch 3:  cost:  0.00151134
# accuracy:  0.747
# Epoch 37, CIFAR-10 Batch 4:  cost:  0.00556873
# accuracy:  0.7484
# Epoch 37, CIFAR-10 Batch 5:  cost:  0.00434606
# accuracy:  0.7478
# Epoch 38, CIFAR-10 Batch 1:  cost:  0.00234468
# accuracy:  0.7568
# Epoch 38, CIFAR-10 Batch 2:  cost:  0.00357206
# accuracy:  0.7474
# Epoch 38, CIFAR-10 Batch 3:  cost:  0.00210139
# accuracy:  0.7478
# Epoch 38, CIFAR-10 Batch 4:  cost:  0.00447266
# accuracy:  0.7486
# Epoch 38, CIFAR-10 Batch 5:  cost:  0.00281619
# accuracy:  0.7484
# Epoch 39, CIFAR-10 Batch 1:  cost:  0.00202175
# accuracy:  0.751
# Epoch 39, CIFAR-10 Batch 2:  cost:  0.00180482
# accuracy:  0.7498
# Epoch 39, CIFAR-10 Batch 3:  cost:  0.000917524
# accuracy:  0.7476
# Epoch 39, CIFAR-10 Batch 4:  cost:  0.00631467
# accuracy:  0.7488
# Epoch 39, CIFAR-10 Batch 5:  cost:  0.0051864
# accuracy:  0.7286
# Epoch 40, CIFAR-10 Batch 1:  cost:  0.00105052
# accuracy:  0.7528
# Epoch 40, CIFAR-10 Batch 2:  cost:  0.00134674
# accuracy:  0.7452
# Epoch 40, CIFAR-10 Batch 3:  cost:  0.00037945
# accuracy:  0.7454
# Epoch 40, CIFAR-10 Batch 4:  cost:  0.00605409
# accuracy:  0.7536
# Epoch 40, CIFAR-10 Batch 5:  cost:  0.0303411
# accuracy:  0.7452
# Epoch 41, CIFAR-10 Batch 1:  cost:  0.000401825
# accuracy:  0.747
# Epoch 41, CIFAR-10 Batch 2:  cost:  0.000848427
# accuracy:  0.7384
# Epoch 41, CIFAR-10 Batch 3:  cost:  0.000915315
# accuracy:  0.7472
# Epoch 41, CIFAR-10 Batch 4:  cost:  0.00236638
# accuracy:  0.7526
# Epoch 41, CIFAR-10 Batch 5:  cost:  0.00247504
# accuracy:  0.7526
# Epoch 42, CIFAR-10 Batch 1:  cost:  0.00120414
# accuracy:  0.7466
# Epoch 42, CIFAR-10 Batch 2:  cost:  0.00223986
# accuracy:  0.7572
# Epoch 42, CIFAR-10 Batch 3:  cost:  0.0147821
# accuracy:  0.7462
# Epoch 42, CIFAR-10 Batch 4:  cost:  0.0148813
# accuracy:  0.7466
# Epoch 42, CIFAR-10 Batch 5:  cost:  0.00237196
# accuracy:  0.7518
# Epoch 43, CIFAR-10 Batch 1:  cost:  0.000343643
# accuracy:  0.7558
# Epoch 43, CIFAR-10 Batch 2:  cost:  0.000785232
# accuracy:  0.747
# Epoch 43, CIFAR-10 Batch 3:  cost:  0.00159329
# accuracy:  0.7472
# Epoch 43, CIFAR-10 Batch 4:  cost:  0.00737792
# accuracy:  0.75
# Epoch 43, CIFAR-10 Batch 5:  cost:  0.00296442
# accuracy:  0.744
# Epoch 44, CIFAR-10 Batch 1:  cost:  0.000377083
# accuracy:  0.7474
# Epoch 44, CIFAR-10 Batch 2:  cost:  0.00341795
# accuracy:  0.7514
# Epoch 44, CIFAR-10 Batch 3:  cost:  0.00203758
# accuracy:  0.7466
# Epoch 44, CIFAR-10 Batch 4:  cost:  0.000727968
# accuracy:  0.7494
# Epoch 44, CIFAR-10 Batch 5:  cost:  0.00481722
# accuracy:  0.7354
# Epoch 45, CIFAR-10 Batch 1:  cost:  0.00117273
# accuracy:  0.7498
# Epoch 45, CIFAR-10 Batch 2:  cost:  0.00215802
# accuracy:  0.748
# Epoch 45, CIFAR-10 Batch 3:  cost:  0.000965898
# accuracy:  0.752
# Epoch 45, CIFAR-10 Batch 4:  cost:  0.000784159
# accuracy:  0.7466
# Epoch 45, CIFAR-10 Batch 5:  cost:  0.0045506
# accuracy:  0.756
# Epoch 46, CIFAR-10 Batch 1:  cost:  0.0068091
# accuracy:  0.7544
# Epoch 46, CIFAR-10 Batch 2:  cost:  0.00129302
# accuracy:  0.7442
# Epoch 46, CIFAR-10 Batch 3:  cost:  0.00046923
# accuracy:  0.7438
# Epoch 46, CIFAR-10 Batch 4:  cost:  0.000303049
# accuracy:  0.7528
# Epoch 46, CIFAR-10 Batch 5:  cost:  0.00177931
# accuracy:  0.7308
# Epoch 47, CIFAR-10 Batch 1:  cost:  0.000466463
# accuracy:  0.7474
# Epoch 47, CIFAR-10 Batch 2:  cost:  0.00112087
# accuracy:  0.7408
# Epoch 47, CIFAR-10 Batch 3:  cost:  0.00105336
# accuracy:  0.733
# Epoch 47, CIFAR-10 Batch 4:  cost:  0.00419281
# accuracy:  0.7468
# Epoch 47, CIFAR-10 Batch 5:  cost:  0.001117
# accuracy:  0.7512
# Epoch 48, CIFAR-10 Batch 1:  cost:  0.000361791
# accuracy:  0.7444
# Epoch 48, CIFAR-10 Batch 2:  cost:  0.0251772
# accuracy:  0.7382
# Epoch 48, CIFAR-10 Batch 3:  cost:  0.00107751
# accuracy:  0.7328
# Epoch 48, CIFAR-10 Batch 4:  cost:  0.00136717
# accuracy:  0.7428
# Epoch 48, CIFAR-10 Batch 5:  cost:  0.000717607
# accuracy:  0.7492
# Epoch 49, CIFAR-10 Batch 1:  cost:  0.000984104
# accuracy:  0.7564
# Epoch 49, CIFAR-10 Batch 2:  cost:  0.00197407
# accuracy:  0.7478
# Epoch 49, CIFAR-10 Batch 3:  cost:  0.00045143
# accuracy:  0.7494
# Epoch 49, CIFAR-10 Batch 4:  cost:  0.0061216
# accuracy:  0.7478
# Epoch 49, CIFAR-10 Batch 5:  cost:  0.0189679
# accuracy:  0.7496
# Epoch 50, CIFAR-10 Batch 1:  cost:  0.000904563
# accuracy:  0.753
# Epoch 50, CIFAR-10 Batch 2:  cost:  0.00122607
# accuracy:  0.7544
# Epoch 50, CIFAR-10 Batch 3:  cost:  0.000492205
# accuracy:  0.7502
# Epoch 50, CIFAR-10 Batch 4:  cost:  0.00366918
# accuracy:  0.7506
# Epoch 50, CIFAR-10 Batch 5:  cost:  0.00119017
# accuracy:  0.747
# Epoch 51, CIFAR-10 Batch 1:  cost:  0.000114172
# accuracy:  0.749
# Epoch 51, CIFAR-10 Batch 2:  cost:  0.00218302
# accuracy:  0.7524
# Epoch 51, CIFAR-10 Batch 3:  cost:  0.000436314
# accuracy:  0.7556
# Epoch 51, CIFAR-10 Batch 4:  cost:  0.00285209
# accuracy:  0.7472
# Epoch 51, CIFAR-10 Batch 5:  cost:  0.00194489
# accuracy:  0.7472
# Epoch 52, CIFAR-10 Batch 1:  cost:  0.00292436
# accuracy:  0.7488
# Epoch 52, CIFAR-10 Batch 2:  cost:  0.000260477
# accuracy:  0.7562
# Epoch 52, CIFAR-10 Batch 3:  cost:  0.00142036
# accuracy:  0.7466
# Epoch 52, CIFAR-10 Batch 4:  cost:  0.00562096
# accuracy:  0.7416
# Epoch 52, CIFAR-10 Batch 5:  cost:  0.00149718
# accuracy:  0.7406
# Epoch 53, CIFAR-10 Batch 1:  cost:  0.000906846
# accuracy:  0.7484
# Epoch 53, CIFAR-10 Batch 2:  cost:  0.000500058
# accuracy:  0.7468
# Epoch 53, CIFAR-10 Batch 3:  cost:  0.000444357
# accuracy:  0.742
# Epoch 53, CIFAR-10 Batch 4:  cost:  0.000582951
# accuracy:  0.744
# Epoch 53, CIFAR-10 Batch 5:  cost:  0.000785778
# accuracy:  0.7464
# Epoch 54, CIFAR-10 Batch 1:  cost:  0.00676791
# accuracy:  0.7484
# Epoch 54, CIFAR-10 Batch 2:  cost:  0.00058079
# accuracy:  0.748
# Epoch 54, CIFAR-10 Batch 3:  cost:  0.000513345
# accuracy:  0.7486
# Epoch 54, CIFAR-10 Batch 4:  cost:  0.00669291
# accuracy:  0.751
# Epoch 54, CIFAR-10 Batch 5:  cost:  0.0038543
# accuracy:  0.7454
# Epoch 55, CIFAR-10 Batch 1:  cost:  0.000565366
# accuracy:  0.7572
# Epoch 55, CIFAR-10 Batch 2:  cost:  0.000336846
# accuracy:  0.7442
# Epoch 55, CIFAR-10 Batch 3:  cost:  0.000152963
# accuracy:  0.7474
# Epoch 55, CIFAR-10 Batch 4:  cost:  0.00259463
# accuracy:  0.7392
# Epoch 55, CIFAR-10 Batch 5:  cost:  0.000737324
# accuracy:  0.7436
# Epoch 56, CIFAR-10 Batch 1:  cost:  0.000942699
# accuracy:  0.7558
# Epoch 56, CIFAR-10 Batch 2:  cost:  0.000197502
# accuracy:  0.749
# Epoch 56, CIFAR-10 Batch 3:  cost:  4.72514e-05
# accuracy:  0.7454
# Epoch 56, CIFAR-10 Batch 4:  cost:  0.000551706
# accuracy:  0.7426
# Epoch 56, CIFAR-10 Batch 5:  cost:  0.00354171
# accuracy:  0.7416
# Epoch 57, CIFAR-10 Batch 1:  cost:  0.000507155
# accuracy:  0.7454
# Epoch 57, CIFAR-10 Batch 2:  cost:  0.000218816
# accuracy:  0.7514
# Epoch 57, CIFAR-10 Batch 3:  cost:  0.000428552
# accuracy:  0.7496
# Epoch 57, CIFAR-10 Batch 4:  cost:  0.00163934
# accuracy:  0.7404
# Epoch 57, CIFAR-10 Batch 5:  cost:  0.000979695
# accuracy:  0.7448
# Epoch 58, CIFAR-10 Batch 1:  cost:  0.00127083
# accuracy:  0.749
# Epoch 58, CIFAR-10 Batch 2:  cost:  6.65686e-05
# accuracy:  0.754
# Epoch 58, CIFAR-10 Batch 3:  cost:  0.000140435
# accuracy:  0.7436
# Epoch 58, CIFAR-10 Batch 4:  cost:  0.00262324
# accuracy:  0.7492
# Epoch 58, CIFAR-10 Batch 5:  cost:  0.00104925
# accuracy:  0.737
# Epoch 59, CIFAR-10 Batch 1:  cost:  0.00115675
# accuracy:  0.7478
# Epoch 59, CIFAR-10 Batch 2:  cost:  0.00194794
# accuracy:  0.7538
# Epoch 59, CIFAR-10 Batch 3:  cost:  0.000156057
# accuracy:  0.7508
# Epoch 59, CIFAR-10 Batch 4:  cost:  0.000324911
# accuracy:  0.751
# Epoch 59, CIFAR-10 Batch 5:  cost:  0.000475734
# accuracy:  0.751
# Epoch 60, CIFAR-10 Batch 1:  cost:  0.00122269
# accuracy:  0.7488
# Epoch 60, CIFAR-10 Batch 2:  cost:  0.000411832
# accuracy:  0.752
# Epoch 60, CIFAR-10 Batch 3:  cost:  0.00024763
# accuracy:  0.75
# Epoch 60, CIFAR-10 Batch 4:  cost:  0.00091923
# accuracy:  0.7438
# Epoch 60, CIFAR-10 Batch 5:  cost:  0.000735694
# accuracy:  0.743

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7327826433121019

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
